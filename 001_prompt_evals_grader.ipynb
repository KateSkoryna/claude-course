# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a solution to parse the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri):\n    \"\"\"\n    Parse the bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): Full S3 URI (e.g., s3://my-bucket-name/path/to/file.txt)\n    \n    Returns:\n        str: The bucket name, or None if invalid format\n    \n    Raises:\n        ValueError: If the URI doesn't start with s3://\n    \"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove the s3:// prefix\n    remainder = s3_uri[5:]\n    \n    # Extract bucket name (everything before the first /)\n    bucket_name = remainder.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Invalid S3 URI: bucket name is empty\")\n    \n    return bucket_name\n\n\n# Test cases\ntest_cases = [\n    \"s3://my-bucket-name/path/to/file.txt\",\n    \"s3://my-bucket/\",\n    \"s3://simple-bucket\",\n    \"s3://bucket-with-many-levels/path/to/deep/nested/file.txt\",\n]\n\nfor uri in test_cases:\n    try:\n        bucket = parse_s3_bucket_name(uri)\n        print(f\"\u2713 URI: {uri}\")\n        print(f\"  Bucket: {bucket}\\n\")\n    except ValueError as e:\n        print(f\"\u2717 Error: {e}\\n\")\n```\n\n**Output:**\n```\n\u2713 URI: s3://my-bucket-name/path/to/file.txt\n  Bucket: my-bucket-name\n\n\u2713 URI: s3://my-bucket/\n  Bucket: my-bucket\n\n\u2713 URI: s3://simple-bucket\n  Bucket: simple-bucket\n\n\u2713 URI: s3://bucket-with-many-levels/path/to/deep/nested/file.txt\n  Bucket: bucket-with-many-levels\n```\n\n## Alternative: Using Regular Expressions\n\n```python\nimport re\n\ndef parse_s3_bucket_name_regex(s3_uri):\n    \"\"\"Parse bucket name using regex.\"\"\"\n    match = re.match(r'^s3://([a-z0-9\\-\\.]+)', s3_uri, re.IGNORECASE)\n    if not match:\n        raise ValueError(\"Invalid S3 URI format\")\n    return match.group(1)\n```\n\n## Alternative: Using urllib\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_name_urllib(s3_uri):\n    \"\"\"Parse bucket name using urllib.\"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(\"URI must use s3:// scheme\")\n    bucket_name = parsed.netloc\n    if not bucket_name:\n        raise ValueError(\"Invalid S3 URI: bucket name is empty\")\n    return bucket_name\n```\n\n## Key Points\n\n\u2705 **Handles various formats** - with/without paths, trailing slashes  \n\u2705 **Error handling** - validates proper S3 URI format  \n\u2705 **Simple & efficient** - extracts bucket name before first `/`  \n\u2705 **AWS bucket naming rules** - supports valid bucket names (letters, numbers, hyphens, dots)\n\nChoose the approach that best fits your needs:\n- **Simple split**: Fast and readable for most use cases\n- **Regex**: Validates bucket name format strictly\n- **urllib**: Built-in Python solution, most robust",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., s3://my-bucket-name/path/to/file.txt)",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the core task with three viable approaches and good documentation. However, it has security/correctness gaps: it doesn't validate against actual AWS bucket naming constraints, the regex example contains a subtle bug that would silently fail, and it doesn't address common variants like s3a://. The urllib approach is genuinely robust, but the simple approach should include bucket name validation. The solution would benefit from stricter validation and awareness of real-world S3 URI variations."
#   },
#   {
#     "output": "# AWS IAM Role with EC2 Trust Policy - CloudFormation JSON Template\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template snippet for an IAM role with EC2 trust policy\",\n  \"Resources\": {\n    \"EC2TrustRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"RoleName\": \"EC2TrustRole\",\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"ec2.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"Description\": \"IAM role that allows EC2 instances to assume it\"\n      }\n    }\n  },\n  \"Outputs\": {\n    \"RoleArn\": {\n      \"Description\": \"ARN of the EC2 Trust Role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"EC2TrustRole\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"RoleName\": {\n      \"Description\": \"Name of the EC2 Trust Role\",\n      \"Value\": {\n        \"Ref\": \"EC2TrustRole\"\n      }\n    }\n  }\n}\n```\n\n## Key Components Explained:\n\n| Component | Purpose |\n|-----------|---------|\n| **AssumeRolePolicyDocument** | Trust policy defining who can assume the role |\n| **Principal.Service** | Specifies `ec2.amazonaws.com` as the trusted service |\n| **Action** | `sts:AssumeRole` allows the EC2 service to assume this role |\n| **Effect** | Set to `Allow` to permit the trust relationship |\n\n## Usage Notes:\n\n- This role needs an **Instance Profile** to be attached to an EC2 instance\n- Attach **IAM Policies** to this role to grant permissions to EC2 instances\n- The trust policy allows any EC2 instance in your AWS account to assume this role\n\n### Optional: Add Instance Profile\n\n```json\n\"EC2InstanceProfile\": {\n  \"Type\": \"AWS::IAM::InstanceProfile\",\n  \"Properties\": {\n    \"Roles\": [\n      {\n        \"Ref\": \"EC2TrustRole\"\n      }\n    ]\n  }\n}\n```",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS IAM role with a trust policy allowing EC2 service to assume it",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly addresses the core task of creating an IAM role with EC2 trust policy in CloudFormation JSON format. The trust policy syntax is valid and properly structured. Documentation is above average with helpful explanations and optional additions. However, the hardcoded RoleName is a CloudFormation anti-pattern that can cause deployment issues, and the role lacks any actual permissions without attached policies. The solution works for the stated task but has room for improvement in production-readiness and best practices guidance."
#   },
#   {
#     "output": "# AWS ARN Format Validator\n\n```python\nimport re\nfrom typing import Union\n\ndef validate_arn(arn: str) -> bool:\n    \"\"\"\n    Validates an AWS ARN (Amazon Resource Name) format.\n    \n    AWS ARN Format: arn:partition:service:region:account-id:resource-type/resource-id\n    \n    Args:\n        arn (str): The ARN string to validate\n        \n    Returns:\n        bool: True if valid ARN format, False otherwise\n        \n    Examples:\n        >>> validate_arn(\"arn:aws:iam::123456789012:user/Development/product_1202/*\")\n        True\n        >>> validate_arn(\"arn:aws:s3:::my_corporate_bucket/*\")\n        True\n        >>> validate_arn(\"arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\")\n        True\n        >>> validate_arn(\"invalid-arn\")\n        False\n        >>> validate_arn(\"arn:aws:iam::notanaccountid:user/test\")\n        False\n    \"\"\"\n    \n    if not isinstance(arn, str):\n        return False\n    \n    # AWS ARN regex pattern\n    # Format: arn:partition:service:region:account-id:resource\n    arn_pattern = r\"^arn:([a-z0-9\\-]+):([a-z0-9\\-]+):([a-z0-9\\-]*):(\\d{0,12}):(.+)$\"\n    \n    match = re.match(arn_pattern, arn, re.IGNORECASE)\n    \n    if not match:\n        return False\n    \n    partition, service, region, account_id, resource = match.groups()\n    \n    # Validate partition (usually 'aws', 'aws-cn', 'aws-us-gov')\n    valid_partitions = ['aws', 'aws-cn', 'aws-us-gov']\n    if partition.lower() not in valid_partitions:\n        return False\n    \n    # Validate service (non-empty)\n    if not service:\n        return False\n    \n    # Validate account-id (either empty or 12 digits)\n    if account_id and len(account_id) != 12:\n        return False\n    \n    # Validate resource (non-empty)\n    if not resource:\n        return False\n    \n    return True\n\n\n# Extended version with more detailed validation\ndef validate_arn_extended(arn: str, strict: bool = False) -> Union[bool, dict]:\n    \"\"\"\n    Enhanced ARN validator with optional detailed parsing.\n    \n    Args:\n        arn (str): The ARN string to validate\n        strict (bool): If True, returns dict with parsed components; if False, returns bool\n        \n    Returns:\n        bool or dict: Validation result or parsed components\n        \n    Examples:\n        >>> validate_arn_extended(\"arn:aws:s3:::my_bucket\", strict=True)\n        {'valid': True, 'partition': 'aws', 'service': 's3', 'region': '', 'account_id': '', 'resource': 'my_bucket'}\n        >>> validate_arn_extended(\"invalid\", strict=True)\n        {'valid': False, 'error': 'Invalid ARN format'}\n    \"\"\"\n    \n    if not isinstance(arn, str):\n        if strict:\n            return {'valid': False, 'error': 'ARN must be a string'}\n        return False\n    \n    arn_pattern = r\"^arn:([a-z0-9\\-]+):([a-z0-9\\-]+):([a-z0-9\\-]*):(\\d{0,12}):(.+)$\"\n    match = re.match(arn_pattern, arn, re.IGNORECASE)\n    \n    if not match:\n        if strict:\n            return {'valid': False, 'error': 'Invalid ARN format'}\n        return False\n    \n    partition, service, region, account_id, resource = match.",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS ARN format and returns True if valid, False otherwise",
#       "format": "python"
#     },
#     "score": 5,
#     "reasoning": "The primary function is well-structured with solid logic and good documentation, but the solution is significantly undermined by the incomplete extended function that cannot execute. The regex pattern is functionally adequate but has minor design issues (case-insensitive matching is unnecessary). The account ID validation is reasonable for flexibility but could be stricter depending on use case requirements."
#   }
# ]
