# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def grade_by_model(test_case, output):
# Out:
#   Cell In[6], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Region Extractor\n\nHere's a comprehensive solution:\n\n```python\nimport re\nfrom typing import Optional\n\ndef extract_s3_region(arn: str) -> str:\n    \"\"\"\n    Extracts the AWS region from an S3 bucket ARN.\n    \n    S3 ARN formats:\n    - Standard bucket ARN (no region): 'arn:aws:s3:::my-bucket'\n    - Bucket with region: 'arn:aws:s3:us-west-2::my-bucket'\n    \n    Args:\n        arn (str): The S3 bucket ARN string\n        \n    Returns:\n        str: The AWS region, or 'us-east-1' if not specified\n        \n    Raises:\n        ValueError: If the ARN format is invalid\n    \"\"\"\n    if not isinstance(arn, str) or not arn.strip():\n        raise ValueError(\"ARN must be a non-empty string\")\n    \n    # Parse the ARN structure: arn:partition:service:region:account-id:resource\n    arn_pattern = r'^arn:aws:s3:([^:]*)::[^:]+$'\n    match = re.match(arn_pattern, arn)\n    \n    if not match:\n        raise ValueError(f\"Invalid S3 ARN format: {arn}\")\n    \n    region = match.group(1)\n    \n    # Return the region if present, otherwise return default\n    return region if region else 'us-east-1'\n\n\n# Alternative version with more lenient parsing\ndef extract_s3_region_lenient(arn: str) -> str:\n    \"\"\"\n    Lenient version that handles various ARN formats.\n    \"\"\"\n    if not isinstance(arn, str) or not arn.strip():\n        raise ValueError(\"ARN must be a non-empty string\")\n    \n    parts = arn.split(':')\n    \n    # Standard ARN has at least 6 parts: arn, aws, s3, region, account, resource\n    if len(parts) < 6:\n        raise ValueError(f\"Invalid S3 ARN format: {arn}\")\n    \n    region = parts[3].strip()\n    return region if region else 'us-east-1'\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # (input, expected_output)\n        ('arn:aws:s3:::my-bucket', 'us-east-1'),\n        ('arn:aws:s3:us-west-2::my-bucket', 'us-west-2'),\n        ('arn:aws:s3:eu-central-1::my-bucket', 'eu-central-1'),\n        ('arn:aws:s3:ap-southeast-1::my-bucket', 'ap-southeast-1'),\n        ('arn:aws:s3:::my-bucket-with-dashes', 'us-east-1'),\n        ('arn:aws:s3:us-east-1::my-bucket', 'us-east-1'),\n    ]\n    \n    print(\"Testing extract_s3_region():\")\n    print(\"-\" * 60)\n    for arn, expected in test_cases:\n        try:\n            result = extract_s3_region(arn)\n            status = \"\u2713 PASS\" if result == expected else \"\u2717 FAIL\"\n            print(f\"{status}: {arn}\")\n            print(f\"   Expected: {expected}, Got: {result}\\n\")\n        except ValueError as e:\n            print(f\"\u2717 ERROR: {arn}\")\n            print(f\"   {e}\\n\")\n    \n    # Test error cases\n    print(\"\\nTesting error cases:\")\n    print(\"-\" * 60)\n    error_cases = [\n        '',\n        'invalid-arn',\n        'arn:aws:ec2:us-west-2:123456789012:instance/i-1234567890abcdef0',\n    ]\n    \n    for arn in error_cases:\n        try:\n            result = extract_s3_region(",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an S3 bucket ARN (e.g., 'arn:aws:s3:::my-bucket'). The function should return the region if present, or 'us-east-1' as the default if not specified."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS S3 Bucket CloudFormation Template\n\nHere's a JSON CloudFormation template snippet that defines an S3 bucket with versioning enabled and public access blocked:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for S3 bucket with versioning and public access blocked\",\n  \"Resources\": {\n    \"MyS3Bucket\": {\n      \"Type\": \"AWS::S3::Bucket\",\n      \"Properties\": {\n        \"BucketName\": \"my-secure-bucket-12345\",\n        \"VersioningConfiguration\": {\n          \"Status\": \"Enabled\"\n        },\n        \"PublicAccessBlockConfiguration\": {\n          \"BlockPublicAcls\": true,\n          \"BlockPublicPolicy\": true,\n          \"IgnorePublicAcls\": true,\n          \"RestrictPublicBuckets\": true\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"BucketName\": {\n      \"Description\": \"Name of the S3 bucket\",\n      \"Value\": {\n        \"Ref\": \"MyS3Bucket\"\n      }\n    },\n    \"BucketArn\": {\n      \"Description\": \"ARN of the S3 bucket\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyS3Bucket\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Features:\n\n| Feature | Configuration |\n|---------|---------------|\n| **Versioning** | `VersioningConfiguration.Status: \"Enabled\"` |\n| **Block Public ACLs** | `true` - Prevents public ACL application |\n| **Block Public Policy** | `true` - Blocks public bucket policies |\n| **Ignore Public ACLs** | `true` - Ignores existing public ACLs |\n| **Restrict Public Buckets** | `true` - Restricts public bucket access |\n\n## Notes:\n\n- Replace `\"my-secure-bucket-12345\"` with a globally unique bucket name\n- All four public access block settings are enabled for maximum security\n- The template includes outputs for the bucket name and ARN\n- Versioning allows you to preserve, retrieve, and restore previous versions of objects",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS S3 bucket resource with versioning enabled and public access blocked."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Role ARN Regular Expression\n\nHere's a comprehensive solution with multiple approaches:\n\n## Solution 1: Basic Capture Groups (Recommended)\n\n```regex\n^arn:aws:iam::(\\d{12}):role/(.+)$\n```\n\n**Explanation:**\n- `^arn:aws:iam::` - Literal prefix\n- `(\\d{12})` - Capture group 1: Account ID (exactly 12 digits)\n- `:role/` - Literal separator\n- `(.+)` - Capture group 2: Role name (one or more characters)\n- `$` - End of string\n\n## Solution 2: Strict Role Name Validation (Production-Ready)\n\n```regex\n^arn:aws:iam::(\\d{12}):role/([a-zA-Z0-9\\-_+=,.@/]+)$\n```\n\n**Explanation:**\n- Allows valid IAM role name characters: alphanumeric, `-`, `_`, `+`, `=`, `,`, `.`, `@`, `/`\n- Complies with AWS IAM naming rules\n\n## Solution 3: With Optional Path\n\n```regex\n^arn:aws:iam::(\\d{12}):role/([a-zA-Z0-9\\-_+=,.@/]+)$\n```\n\nHandles role names with paths like `role/service/MyRole`\n\n---\n\n## Implementation Examples\n\n### JavaScript\n```javascript\nconst arnRegex = /^arn:aws:iam::(\\d{12}):role\\/([a-zA-Z0-9\\-_+=,.@\\/]+)$/;\n\nconst arn = 'arn:aws:iam::123456789012:role/MyRoleName';\nconst match = arn.match(arnRegex);\n\nif (match) {\n  console.log('Account ID:', match[1]);      // 123456789012\n  console.log('Role Name:', match[2]);       // MyRoleName\n}\n```\n\n### Python\n```python\nimport re\n\narn_pattern = r'^arn:aws:iam::(\\d{12}):role/([a-zA-Z0-9\\-_+=,.@/]+)$'\n\narn = 'arn:aws:iam::123456789012:role/MyRoleName'\nmatch = re.match(arn_pattern, arn)\n\nif match:\n    print('Account ID:', match.group(1))     # 123456789012\n    print('Role Name:', match.group(2))      # MyRoleName\n```\n\n### Go\n```go\npackage main\n\nimport (\n    \"fmt\"\n    \"regexp\"\n)\n\nfunc main() {\n    pattern := `^arn:aws:iam::(\\d{12}):role/([a-zA-Z0-9\\-_+=,.@/]+)$`\n    regex := regexp.MustCompile(pattern)\n    \n    arn := \"arn:aws:iam::123456789012:role/MyRoleName\"\n    matches := regex.FindStringSubmatch(arn)\n    \n    if matches != nil {\n        fmt.Println(\"Account ID:\", matches[1])     // 123456789012\n        fmt.Println(\"Role Name:\", matches[2])      // MyRoleName\n    }\n}\n```\n\n---\n\n## Test Cases\n\n```\n\u2713 arn:aws:iam::123456789012:role/MyRole\n\u2713 arn:aws:iam::999999999999:role/service-role\n\u2713 arn:aws:iam::000000000000:role/my-role_name\n\u2713 arn:aws:iam::123456789012:role/path/to/MyRole\n\n\u2717 arn:aws:iam::12345678901:role/MyRole        (11 digits)\n\u2717 arn:aws:iam::1234567890123:role/MyRole      (13 digits)\n\u2717 arn:aws:iam:us-east-1:123456789012:role/MyRole  (invalid service)\n\u2717 arn:aws:iam::123456789012:role",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS IAM role ARNs in the format 'arn:aws:iam::123456789012:role/RoleName' and captures the account ID and role name separately."
#     },
#     "score": 10
#   }
# ]
